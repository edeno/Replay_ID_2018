# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'
# %qtconsole

# %%
import pandas as pd
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

import logging
logging.basicConfig(level=logging.INFO)

# %%
import itertools
import logging
import sys
from argparse import ArgumentParser
from os.path import join
from signal import SIGUSR1, SIGUSR2, signal
from subprocess import PIPE, run

import matplotlib.pyplot as plt
import numpy as np

from replay_identification import ReplayDetector
from src.load_data import load_data
from src.parameters import (ANIMALS, BRAIN_AREAS, FIGURE_DIR,
                            SAMPLING_FREQUENCY, USE_LIKELIHOODS)
from src.save_data import save_overlap, save_replay_data
from src.summarize_replay import (add_epoch_info_to_dataframe, compare_overlap,
                                  decode_replays, get_replay_times,
                                  summarize_replays)
from src.visualization import plot_behavior

epoch_key = ('bon', 3, 2)

animals = ANIMALS
sampling_frequency = SAMPLING_FREQUENCY
use_likelihoods = USE_LIKELIHOODS
position_metric='linear_distance'
speed_metric='linear_speed'
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.bk-hbox {
#     display: flex;
#     justify-content: center;
# }
#
# div.bk-hbox div.bk-plot {
#     padding: 8px;
# }
#
# div.bk-hbox div.bk-data-table {
#     padding: 20px;
# }
#
# div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
# ...

# %%
animal, day, epoch = epoch_key
data_types = {'spikes', 'multiunit'}
data = load_data(epoch_key, animals, sampling_frequency, data_types,
                 BRAIN_AREAS, speed_metric)
# Out:
# INFO:src.load_data:Loading Data...
# WARNING:loren_frank_data_processing.core:Failed to load file: /Users/edeno/Documents/GitHub/Replay_ID_2018/src/../Raw-Data/Bond/bonDIO03.mat
# WARNING:loren_frank_data_processing.core:No DIO file found, using distance from well to segment trials
# WARNING:loren_frank_data_processing.core:Failed to load file: /Users/edeno/Documents/GitHub/Replay_ID_2018/src/../Raw-Data/Bond/bonDIO03.mat
# WARNING:loren_frank_data_processing.core:No DIO file found, inferring correct inbound/outbound from task rules
# WARNING:loren_frank_data_processing.core:dav, 1, 4 not processed
# WARNING:loren_frank_data_processing.core:egy, 12, 1 not processed
# WARNING:loren_frank_data_processing.core:egy, 12, 2 not processed
# WARNING:loren_frank_data_processing.core:egy, 12, 3 not processed
# WARNING:loren_frank_data_processing.core:egy, 12, 4 not processed
# WARNING:loren_frank_data_processing.core:egy, 12, 5 not processed
# ...

# %%
from replay_classification import SortedSpikeDecoder

decoder = SortedSpikeDecoder(
    place_bin_size=2.8,
    replay_speedup_factor=1,
    knot_spacing=15,
    spike_model_penalty=1E-1,
    replay_orders=['Forward']
).fit(
    position=data['position_info'][position_metric].values,
    spikes=data['spikes'].values,
    initial_conditions='Uniform')
# Out:
# INFO:replay_classification.decoders:Fitting state transition model...
# INFO:replay_classification.decoders:Fitting observation model...
# ...

# %%
position_info = data['position_info']

trial_ids = (position_info
            .loc[position_info.is_correct]
            .labeled_segments.unique())


for trial_id in trial_ids:
    plt.figure()
    p = position_info.loc[position_info.labeled_segments == trial_id]
    estimated_position = results.results.position[
        np.log(results.results.posterior_density.squeeze()).argmax('position')]
    rmse = np.sqrt(mean_squared_error(p.linear_distance, estimated_position))
    results = decoder.predict(data['spikes'].loc[p.index], time=p.index.total_seconds())
    results.results.posterior_density.squeeze().plot(x='time', y='position', robust=True)
    plt.plot(p.index.total_seconds(), p.linear_distance.values, color='white', linestyle='--');
    estimated_position.plot(x='time', color='red', linewidth=0.5)
    plt.suptitle(f'Trial ID = {trial_id}, RMSE={rmse:.02f}')

# %%
from replay_classification import ClusterlessDecoder

decoder = ClusterlessDecoder(
    place_bin_size=2.8,
    replay_speedup_factor=1,
    replay_orders=['Forward']
).fit(
    position=data['position_info'][position_metric].values,
    multiunits=data['multiunit'].transpose('tetrodes', 'time', 'features'),
    initial_conditions='Uniform')
# Out:
# INFO:replay_classification.decoders:Fitting state transition model...
# INFO:replay_classification.decoders:Fitting observation model...
# ...

# %%
from sklearn.metrics import mean_squared_error

trial_ids = (position_info
            .loc[position_info.is_correct]
            .labeled_segments.unique())

for trial_id in trial_ids:
    p = position_info.loc[position_info.labeled_segments == trial_id]
    results = decoder.predict(
        data['multiunit'].transpose('tetrodes', 'time', 'features').sel(time=p.index),
        time=p.index.total_seconds())

    estimated_position = results.results.position[
        np.log(results.results.posterior_density.squeeze()).argmax('position')]

    rmse = np.sqrt(mean_squared_error(p.linear_distance, estimated_position))

    plt.figure()
    results.results.posterior_density.squeeze().plot(x='time', y='position', robust=True)
    plt.plot(p.index.total_seconds(), p.linear_distance.values, color='white', linestyle='--');
    estimated_position.plot(x='time', color='red', linewidth=0.5)
    plt.suptitle(f'Trial ID = {trial_id}, RMSE={rmse:.02f}');
# Out:
# ...
# Text(0.5, 0.98, '26.0')
